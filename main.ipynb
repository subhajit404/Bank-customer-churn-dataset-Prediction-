# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Bank Customer Churn Prediction.csv')

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  str
#  3   gender            10000 non-null  str
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), str(2)
# memory usage: 1.0 MB

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='str')

# %%
df.describe().columns
# Out:
# Index(['customer_id', 'credit_score', 'age', 'tenure', 'balance',
#        'products_number', 'credit_card', 'active_member', 'estimated_salary',
#        'churn'],
#       dtype='str')

# %%
numeric_cols = ['customer_id', 'credit_score', 'age', 'tenure', 'balance',
       'products_number', 'estimated_salary']
for col in numeric_cols:
    plt.figure(figsize=(4,4))
    sns.histplot(df[col],kde=True,bins=50)

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df['country'].value_counts()
# Out:
# country
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
sns.countplot(x=df['country'])
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %%
sns.countplot(x=df['products_number'])
# Out:
# <Axes: xlabel='products_number', ylabel='count'>

# %%
sns.countplot(x=df['tenure'])
# Out:
# <Axes: xlabel='tenure', ylabel='count'>

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='str')

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['country', 'gender'], dtype='str')

# %%
df['age'].value_counts()
# Out:
# age
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: count, Length: 70, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df_encoded = pd.get_dummies(df)

# %%
df_encoded=df_encoded.astype(int)

# %%
df_encoded
# Out:
#       customer_id  credit_score  age  tenure  balance  products_number  \
# 0        15634602           619   42       2        0                1
# 1        15647311           608   41       1    83807                1
# 2        15619304           502   42       8   159660                3
# 3        15701354           699   39       1        0                2
# 4        15737888           850   43       2   125510                1
# ...           ...           ...  ...     ...      ...              ...
# 9995     15606229           771   39       5        0                2
# 9996     15569892           516   35      10    57369                1
# 9997     15584532           709   36       7        0                1
# 9998     15682355           772   42       3    75075                2
# 9999     15628319           792   28       4   130142                1
#
#       credit_card  active_member  estimated_salary  churn  country_France  \
# ...

# %%
x = df_encoded.drop('churn',axis=1)
y= df_encoded['churn']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,f1_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,classification_report
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
scaler  =StandardScaler()

# %%
x_train_scaler = scaler.fit_transform(x_train)
x_test_scaler = scaler.fit_transform(x_test)

# %%
x_train_scaler
# Out:
# array([[-1.24645641,  0.35649971, -0.6557859 , ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [ 1.05381124, -0.20389777,  0.29493847, ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [ 0.3664786 , -0.96147213, -1.41636539, ...,  1.73494238,
#         -0.91324755,  0.91324755],
#        ...,
#        [-1.6259648 ,  0.86500853, -0.08535128, ..., -0.57638802,
#          1.09499335, -1.09499335],
#        [ 1.62852321,  0.15932282,  0.3900109 , ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [ 0.21718071,  0.47065475,  1.15059039, ..., -0.57638802,
#         -0.91324755,  0.91324755]], shape=(8000, 14))

# %%
models = {
    'KNN':KNeighborsClassifier(),
    'SVM':SVC(),
    'Naive Bayes':GaussianNB(),
    'LogisticRegression':LogisticRegression(),
    'DecisionTree':DecisionTreeClassifier(),
}

# %%
results = []

for name, model in models.items():
   model.fit(x_train_scaler,y_train)
   y_pred = model.predict(x_test_scaler)
   accuracy = accuracy_score(y_test,y_pred)
   results.append({
      'Model' : name,
      'Accuracy':accuracy
   })

# %% [markdown]
# # **All Model Model Testing Output**

# %%
results
# Out:
# [{'Model': 'KNN', 'Accuracy': 0.8305},
#  {'Model': 'SVM', 'Accuracy': 0.8545},
#  {'Model': 'Naive Bayes', 'Accuracy': 0.8185},
#  {'Model': 'LogisticRegression', 'Accuracy': 0.8105},
#  {'Model': 'DecisionTree', 'Accuracy': 0.7905}]

# %% [markdown]
# # **Ensemble Learning**

# %% [markdown]
# # **Stacking**

# %%
base_larners = [
    ('SVM',SVC(probability=True,random_state=42,kernel='rbf')),
    ('KNN',KNeighborsClassifier()),
    ('Naive Bayes',GaussianNB())
]

# %%
meta_larners = SVC(probability=True,random_state=42,kernel='rbf')

# %%
stacking_clf=StackingClassifier(
    estimators=base_larners,
    final_estimator=meta_larners,
    cv=20
)

# %%
stacking_clf.fit(x_train,y_train)
# Out:
# StackingClassifier(cv=20,
#                    estimators=[('SVM', SVC(probability=True, random_state=42)),
#                                ('KNN', KNeighborsClassifier()),
#                                ('Naive Bayes', GaussianNB())],
#                    final_estimator=SVC(probability=True, random_state=42))

# %%
y_predict_stack=stacking_clf.predict(x_test)

# %%
y_predict_stack
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(2000,))

# %%
accuracy_stack= accuracy_score(y_test,y_predict_stack)

# %%
accuracy_stack
# Out:
# 0.806

# %% [markdown]
# # **Bagging**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    max_depth=None
)

# %%
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_predict_Bagging_rf = rf_model.predict(x_test)

# %%
accuracy =  accuracy_score(y_test,y_predict_Bagging_rf)

# %%
accuracy
# Out:
# 0.8635

# %% [markdown]
# # **Boosting**

# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %% [markdown]
# # **Ada Boosting**

# %%
ada_model =AdaBoostClassifier(n_estimators=100,random_state=42)

# %%
ada_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
y_predict_adaBoost =ada_model.predict(x_test)

# %%
accuracy= accuracy_score(y_test,y_predict_adaBoost)

# %%
accuracy
# Out:
# 0.8595

# %% [markdown]
# # **GradientBoosting Classifier**

# %%
gb_model = GradientBoostingClassifier(n_estimators=100,random_state=42,learning_rate=0.1)

# %%
gb_model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_predict_gbBoost = gb_model.predict(x_test)

# %%
accuracy =accuracy_score(y_test,y_predict_gbBoost)

# %%
accuracy
# Out:
# 0.8635

# %% [markdown]
# # **Xg Boost**

# %%
from xgboost import XGBClassifier

# %%
xg_model = XGBClassifier(
    objective='binary:logistic',
    learning_rate=0.1,     
    max_depth=6,            
    n_estimators=100,      
    subsample=0.8,          
    colsample_bytree=0.8,   
    reg_alpha=0.1,       
    reg_lambda=1,         
    gamma=0,              
    booster='gbtree',    
    tree_method='auto',    
    scale_pos_weight=1,
    random_state =42
)

# %%
xg_model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict_xgBoost = xg_model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_xgBoost)

# %%
accuracy
# Out:
# 0.8675
